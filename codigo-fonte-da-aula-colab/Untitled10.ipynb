# %%
N = int(input())

for _ in range(N):
    X, Y = map(int, input().split())
    menor = min(X, Y)
    maior = max(X, Y)
    soma = 0
    for i in range(menor + 1, maior):
        if i % 2 != 0:
            soma += i
    print(soma)
# Out:
# 7
# 4 5
# 0
# 13 10
# 11
# 6 4
# 5
# 3 3
# 0
# 3 5
# 0
# 3 4
# 0
# 3 8
# 12
